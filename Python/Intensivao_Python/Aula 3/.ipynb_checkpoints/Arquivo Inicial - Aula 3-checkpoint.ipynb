# %% [markdown]
# # Automação Web e Busca de Informações com Python
#
# #### Desafio:
#
# Trabalhamos em uma importadora e o preço dos nossos produtos é vinculado a cotação de:
# - Dólar
# - Euro
# - Ouro
#
# Precisamos pegar na internet, de forma automática, a cotação desses 3 itens e saber quanto devemos cobrar pelos nossos produtos, considerando uma margem de contribuição que temos na nossa base de dados.
#
# Base de Dados: https://drive.google.com/drive/folders/1KmAdo593nD8J9QBaZxPOG1yxHZua4Rtv?usp=sharing
#
# Para isso, vamos criar uma automação web:
#
# - Usaremos o selenium
# - Importante: baixar o webdriver

# %% [markdown]
# ## Dicas:
#
# <ul>
#     <li>O Selenium permite controlar tudo no seu computador</li>
#     <li>Quando se estiver usando Selenium, sempre que for passar o XPATH, coloque o XPATH entre aspas simples</li>
# </ul>

# %%
# !pip3 install selenium

# %%
# Teste webdriver
# from selenium import webdriver
# browser = webdriver.Chrome()
# browser.get('http://www.ubuntu.com')

# %%
## # Logica

# Selenium
    # criar um navegador
    # entrar em sites
    # encontrar informacoes / itens no site
    # fechar o navegador
    
# Passo 1: Pegar a cotacao do Dolar

# Passo 2: Pegar a cotacao do Euro

# Passo 3: Pegar a cotacao do Ouro

# Passo 4: Importar a base e Atualizar as cotacoes da minha base

# Passo 5: Calcular os novos precos e salvar/exportar a base de dados

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


navegador = webdriver.Chrome()
    
# Passo 1: Pegar a cotacao do Dolar
navegador.get("https://google.com.br/")

navegador.find_element(By.XPATH, 
                       '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input').send_keys("cotacao dolar")

navegador.find_element(By.XPATH, 
                       '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input').send_keys(Keys.ENTER)

cotacao_dolar = navegador.find_element(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')
print(cotacao_dolar)

# Passo 2: Pegar a cotacao do Euro
navegador.get("https://google.com.br/")

navegador.find_element(By.XPATH, 
                       '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input').send_keys("cotacao euro")

navegador.find_element(By.XPATH, 
                       '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input').send_keys(Keys.ENTER)

cotacao_euro = navegador.find_element(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')
print(cotacao_euro)


# Passo 3: Pegar a cotacao do Ouro
navegador.get("https://www.melhorcambio.com/ouro-hoje")

cotacao_ouro = navegador.find_element(By.XPATH, '//*[@id="comercial"]').get_attribute("value")
cotacao_ouro  = cotacao_ouro.replace(",", ".")
print(cotacao_ouro)
# Out:
# 5.515899999999999
# 6.328800246
# 323.26

# %% [markdown]
# ### Agora vamos atualiza a nossa base de preços com as novas cotações

# %% [markdown]
# - Importando a base de dados

# %%
# Passo 4: Importar a base e Atualizar as cotacoes da minha base
import pandas as pd

tabela = pd.read_excel('./Produtos.xlsx')
display(tabela)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %% [markdown]
# - Atualizando os preços e o cálculo do Preço Final

# %%
# Passo 5: Calcular os novos precos e salvar/exportar a base de dados
tabela.loc[tabela["Moeda"] == 'Dólar', "Cotação"] = float(cotacao_dolar)
tabela.loc[tabela["Moeda"] == 'Euro', "Cotação"] = float(cotacao_euro)
tabela.loc[tabela["Moeda"] == 'Ouro', "Cotação"] = float(cotacao_ouro)


# atualizar as colunas

# Preco de Compra = Preco Original * Cotacao
tabela["Preço de Compra"] = tabela["Preço Original"] * tabela["Cotação"]

# Preco de Venda = Preco de Compra * Margem de Lucro
tabela["Preço de Venda"] = tabela["Preço de Compra"] * tabela["Margem"]

display(tabela)
# Out:
#          Produtos  Preço Original  Moeda   Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.5159      5515.844841    1.40
# 1   Carro Renault         4500.00   Euro    6.3288     28479.601107    2.00
# 2   Notebook Dell          899.99  Dólar    5.5159      4964.254841    1.70
# 3          IPhone          799.00  Dólar    5.5159      4407.204100    1.70
# 4      Carro Fiat         3000.00   Euro    6.3288     18986.400738    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.5159      2650.279632    2.00
# 6        Joia 20g           20.00   Ouro  323.2600      6465.200000    1.15
#
#    Preço de Venda
# 0     7722.182777
# 1    56959.202214
# 2     8439.233230
# 3     7492.246970
# 4    36074.161402
# 5     5300.559264
# 6     7434.980000

# %% [markdown]
# ### Agora vamos exportar a nova base de preços atualizada

# %%
tabela.to_excel("Produtos Novo.xlsx", index=False)
