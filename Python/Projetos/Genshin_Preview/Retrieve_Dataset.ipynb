# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve, Request
from urllib.error import URLError, HTTPError
from bs4 import BeautifulSoup

# %% [markdown]
# # Criando uma lista com os nome dos personagens

# %%
# Fazendo requisicao para  a URL
url = 'https://genshin.honeyhunterworld.com/db/char/characters/?lang=EN'
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0'}

# Declarando variaveis
lista = []

# Realizando um tratamento de erro caso a requisicao nao funcione
try:
    # Obtendo HTML
    req = Request(url, headers = headers)
    response = urlopen(req)
    html = response.read().decode('utf-8')
    
    # Tratamento de HTML -> String
    def trata_html(input):
        return " ".join(input.split()).replace('> <', '><')
    
    html = trata_html(html)
    
    # Utilizando do BeautifulSoup para obter o nome dos personagens
    soup = BeautifulSoup(html, 'html.parser')
    dados = soup.find('div', {'class': 'wrappercont wrappercont_char'}).findAll('div', class_='char_sea_cont')
    
    # Coletando nome dos personagens
    for dado in dados:
        lista.append(dado.find('span', {'class': 'sea_charname'}).get_text())
        
    print(lista)
    
except HTTPError as e:
    print(e.status, e.reason)
    
except URLError as e:
    print(e.reason)
# Out:
# ['Amber', 'Barbara', 'Beidou', 'Bennett', 'Chongyun', 'Diluc', 'Fischl', 'Jean', 'Kaeya', 'Keqing', 'Klee', 'Lisa', 'Mona', 'Ningguang', 'Noelle', 'Qiqi', 'Razor', 'Sucrose', 'Traveler', 'Traveler', 'Venti', 'Xiangling', 'Xiao', 'Xingqiu', 'Tartaglia', 'Zhongli', 'Diona', 'Xinyan', 'Ganyu', 'Albedo', 'Rosaria', 'Kamisato Ayaka', 'Hu Tao', 'Yanfei', 'Eula', 'Traveler', 'Traveler', 'Kaedehara Kazuha', 'Yoimiya', 'Sayu', 'Traveler', 'Traveler', 'Raiden Shogun', 'Sangonomiya Kokomi', 'Aloy', 'Kujou Sara', 'Thoma', 'Gorou', 'Arataki Itto']

# %%
url = 'https://genshin-impact.fandom.com/wiki/Characters/Comparison'

response = urlopen(url)
html = response.read().decode('utf-8')

lista_personagens = {}

# Tratamento de HTML -> String
def trata_html(input):
    return " ".join(input.split()).replace('> <', '><')
    
html = trata_html(html)

soup = BeautifulSoup(html, 'html.parser')

aba = soup.find('div', class_='mw-parser-output').find('table', {'class': "article-table sortable"})

titulos = aba.find('tr').get_text().split()

ascension_stat = titulos[5] + " " + titulos[6]
ascension_stat_value = titulos[7] + " " + titulos[8] + " " + titulos[9]

titulos.append(ascension_stat)
titulos.append(ascension_stat_value)

print(titulos)

titulos = set(titulos)


titulos.remove('Ascension')

titulos.remove('Stat')

titulos.remove('Value')


titulos = list(titulos)

print(titulos)

dados = aba.find('tbody').findAll('tr')

dados.pop(0)

for dado in dados:
    print(dado.find('td').find('a').find('title', class_='Albedo'))
# Out:
# ['Icon', 'Name', 'HP', 'ATK', 'DEF', 'Ascension', 'Stat', 'Ascension', 'Stat', 'Value', 'Ascension Stat', 'Ascension Stat Value']
# ['HP', 'Ascension Stat', 'DEF', 'Name', 'ATK', 'Ascension Stat Value', 'Icon']
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# # Buscando as infos de cada personagem

# %%
# Fazendo requisicao para o URL
url = 'https://genshin.honeyhunterworld.com/db/char/characters/?lang=EN'
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0'}

# Declarando variaveis
infos = {}

## Obtendo o HTML
req = Request(url, headers = headers)
response = urlopen(req)
html = response.read().decode('utf-8')

## Iterano por todas as paginas do site
# for i in range(len(lista)):
print(lista[0])
    ## Obtendo o HTML
#     if lista[0] == "Hu Tao":
#         armazem = lista[i].split()
#         novo_nome = "".join(armazem)
#         url = 'https://genshin.honeyhunterworld.com/db/char/' + novo_nome.lower() +'/?lang=EN'
#     elif lista[i] == 'Yanfei':
#         lista[i] = 'Feiyan'
#         url = 'https://genshin.honeyhunterworld.com/db/char/' + lista[i].lower() +'/?lang=EN'
#     elif lista[i] == 'Raiden Shogun':
#         lista[i] = 'Shougun'
#         url = 'https://genshin.honeyhunterworld.com/db/char/' + lista[i].lower() +'/?lang=EN'
#     elif len(lista[i].split()) > 1:
#         nova_lista = lista[i].split()
#         nome = nova_lista[1]
#         url = 'https://genshin.honeyhunterworld.com/db/char/' + nome.lower() +'/?lang=EN'
#     else:
#         url = 'https://genshin.honeyhunterworld.com/db/char/' + lista[i].lower() +'/?lang=EN'

url = 'https://genshin.honeyhunterworld.com/db/char/' + lista[0].lower() +'/?lang=EN'
      
subheader = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0'}
req = Request(url, headers = headers)
response = urlopen(req)
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
    
pagina = soup.find('table', 'item_main_table').findAll('tr')

for item in pagina:
    item.find('td')
    print(item.find('a'))

print(pagina)
#     infos['nome'] = lista[i]
#     infos['HP_base'] = tabela_de_informacoes.findAll('tr')
    
#     print(infos)
# Out:
# Amber
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
